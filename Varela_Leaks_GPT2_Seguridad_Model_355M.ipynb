# %% [markdown]
# - GPT-2 Final Release    - https://openai.com/blog/gpt-2-1-5b-release/
# - GPT-2 Fine Tunning     - https://github.com/nshepperd/gpt-2/tree/finetuning
# - GPT-2 Beginners Guide  - https://medium.com/@ngwaifoong92/beginners-guide-to-retrain-gpt-2-117m-to-generate-custom-text-content-8bb5363d8b7f
# - GPT-2 How To           - https://minimaxir.com/2019/09/howto-gpt2/
# - GPT-2 Generating Jokes - https://pmbaumgartner.github.io/blog/gpt2-jokes/

# %%
GITHUB_REPO = 'https://github.com/nshepperd/gpt-2.git'

# %%
# !git clone $GITHUB_REPO
# Out:
# Cloning into 'gpt-2'...
# remote: Enumerating objects: 310, done.
# remote: Total 310 (delta 0), reused 0 (delta 0), pack-reused 310
# Receiving objects: 100% (310/310), 4.40 MiB | 6.50 MiB/s, done.
# Resolving deltas: 100% (167/167), done.

# %%
# !pip install -r gpt-2/requirements.txt
# Out:
# ...
#      |████████████████████████████████| 81kB 4.9MB/s
# ...
#      |████████████████████████████████| 604kB 20.9MB/s
# ...
#      |████████████████████████████████| 51kB 7.0MB/s
# ...
#   Created wheel for fire: filename=fire-0.2.1-py2.py3-none-any.whl size=103527 sha256=7332d197e6e79f347afed5e1e61742bb1459a7feb336d147a1f55d985e16d2e0
#   Stored in directory: /root/.cache/pip/wheels/31/9c/c0/07b6dc7faf1844bb4688f46b569efe6cafaa2179c95db821da
# ...
#   Created wheel for regex: filename=regex-2017.4.5-cp36-cp36m-linux_x86_64.whl size=533174 sha256=c7b86a2225765b5c8709c8c746d29f98e2e00baf4dc2552dce1b3f5e1696c331
#   Stored in directory: /root/.cache/pip/wheels/75/07/38/3c16b529d50cb4e0cd3dbc7b75cece8a09c132692c74450b01
# Successfully built fire regex
# ...
#   Found existing installation: tqdm 4.28.1
#     Uninstalling tqdm-4.28.1:
#       Successfully uninstalled tqdm-4.28.1
# ...

# %%
# !python gpt-2/download_model.py 355M
# Out:
# Fetching checkpoint: 1.00kit [00:00, 764kit/s]
# Fetching encoder.json: 1.04Mit [00:00, 40.4Mit/s]
# Fetching hparams.json: 1.00kit [00:00, 1.03Mit/s]
# Fetching model.ckpt.data-00000-of-00001: 1.42Git [00:27, 50.8Mit/s]
# Fetching model.ckpt.index: 11.0kit [00:00, 3.48Mit/s]
# Fetching model.ckpt.meta: 927kit [00:00, 35.1Mit/s]
# Fetching vocab.bpe: 457kit [00:00, 37.4Mit/s]

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-ca8a76fb-93dc-461a-baa9-98d206655ded" name="files[]" multiple disabled />
#      <output id="result-ca8a76fb-93dc-461a-baa9-98d206655ded">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving _chat.txt to _chat.txt
# User uploaded file "_chat.txt" with length 1318534 bytes

# %%
# !mv gpt-2/encode.py gpt-2/src/

# %%
# !python gpt-2/src/encode.py --model_name 355M _chat.txt _chat.npz
# Out:
# Reading files
# 100% 1/1 [00:03<00:00,  3.09s/it]
# Writing _chat.npz

# %%
# !mv gpt-2/train.py gpt-2/src

# %%
# !python gpt-2/src/train.py --model_name 355M --sample_every 5 --sample_num 1 --batch_size 1 --learning_rate 0.0001 --dataset _chat.npz
# Out:
# WARNING:tensorflow:From /content/gpt-2/src/model.py:147: The name tf.AUTO_REUSE is deprecated. Please use tf.compat.v1.AUTO_REUSE instead.
#
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From /content/gpt-2/src/memory_saving_gradients.py:13: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# WARNING:tensorflow:From gpt-2/src/train.py:88: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From gpt-2/src/train.py:91: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# ...

# %%
# !mkdir seguridad
# !cp checkpoint/run1/checkpoint seguridad
# !cp checkpoint/run1/model-3000.data-00000-of-00001 seguridad
# !cp checkpoint/run1/model-3000.index seguridad
# !cp checkpoint/run1/model-3000.meta seguridad
# !cp models/355M/encoder.json seguridad
# !cp models/355M/hparams.json seguridad
# !cp models/355M/vocab.bpe seguridad
# !cp gpt-2/src/interactive_conditional_samples.py seguridad
# !cp gpt-2/src/generate_unconditional_samples.py seguridad
# !cp gpt-2/src/model.py seguridad
# !cp gpt-2/src/sample.py seguridad
# !cp gpt-2/src/encoder.py seguridad
# !cp gpt-2/src/encode.py seguridad
# !mv seguridad models

# %%
# !python models/seguridad/generate_unconditional_samples.py --model_name seguridad
# Out:
# WARNING:tensorflow:From /content/models/seguridad/model.py:147: The name tf.AUTO_REUSE is deprecated. Please use tf.compat.v1.AUTO_REUSE instead.
#
# WARNING:tensorflow:From models/seguridad/generate_unconditional_samples.py:52: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# 2019-11-14 04:09:21.880756: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2019-11-14 04:09:21.906128: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-11-14 04:09:21.907028: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla P100-PCIE-16GB major: 6 minor: 0 memoryClockRate(GHz): 1.3285
# pciBusID: 0000:00:04.0
# ...

# %%
# !python models/seguridad/generate_unconditional_samples.py --temperature 0.7 --top_k 10 --model_name seguridad
# Out:
# WARNING:tensorflow:From /content/models/seguridad/model.py:147: The name tf.AUTO_REUSE is deprecated. Please use tf.compat.v1.AUTO_REUSE instead.
#
# WARNING:tensorflow:From models/seguridad/generate_unconditional_samples.py:52: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# 2019-11-14 04:10:50.172922: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2019-11-14 04:10:50.188997: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-11-14 04:10:50.189926: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla P100-PCIE-16GB major: 6 minor: 0 memoryClockRate(GHz): 1.3285
# pciBusID: 0000:00:04.0
# ...

# %%
# !python models/seguridad/interactive_conditional_samples.py --temperature 0.7 --top_k 10 --model_name seguridad
# Out:
# WARNING:tensorflow:From /content/models/seguridad/model.py:147: The name tf.AUTO_REUSE is deprecated. Please use tf.compat.v1.AUTO_REUSE instead.
#
# WARNING:tensorflow:From models/seguridad/interactive_conditional_samples.py:55: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# 2019-11-14 04:12:13.582501: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2019-11-14 04:12:13.599822: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-11-14 04:12:13.600682: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla P100-PCIE-16GB major: 6 minor: 0 memoryClockRate(GHz): 1.3285
# pciBusID: 0000:00:04.0
# ...
